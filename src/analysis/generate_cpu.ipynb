# %%
import os

import transformers

pipeline = transformers.pipeline(
    "text-generation",
    model="google/gemma-3-4b-it",
    device_map="cpu",
    torch_dtype="bfloat16",
)

# %%
# %%timeit
pipeline("hello world", max_new_tokens=8)
